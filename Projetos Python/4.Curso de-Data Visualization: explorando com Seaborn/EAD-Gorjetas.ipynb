# %% [markdown]
# # importando base de dados

# %%
import pandas as pd

# %%
pd.read_csv('data/tips.csv')
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
#total_bill: valor total da conta paga pelo cliente
#tip: valor da gorjeta em si
#dessert: se a pessoa pediu sobremesa ou não
#day: dia da semana
#time: horário de almoço ou horário de jantar
#size: quantidade de clientes na mesa

# %%
data = pd.read_csv('data/tips.csv') #armazeno na variavel data

# %%
data
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
data.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %% [markdown]
# ## Renomeando as colunas

# %% [markdown]
# # Tradução

# %%
data.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
rename = {
    'total_bill' : 'valor_da_conta',
    'tip' : 'gorjeta',
    'dessert' : 'sobremesa',
    'day' : 'dia_da_semana',
    'time' : 'hora_do_dia', 
    'size' : 'total_de_pessoas'
}

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas = data.rename(columns = rename)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.sobremesa.unique() #traz todos os valores que tem em sobremesa
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
yes_no = {
    'No' : 'Não', 
    'Yes' : 'Sim'
}

# %%
gorjetas.sobremesa.map(yes_no)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(yes_no)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
days = {
    'Sun' : 'Domingo',
    'Sat' : 'Sábado',
    'Thur' : 'Quinta',
    'Fri' : 'Sexta'
}

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(days)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
time = {
    'Dinner' : 'Jantar',
    'Lunch' : 'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(time)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
#Exibir as 5 ultimas linhas do DataFrame:

#gorjetas.tail()

#Listar as colunas presentes no DataFrame:

#gorjetas.columns

#Exibir a quantidade de linhas e colunas presentes no DataFrame:

#gorjetas.shape

#Deletar uma coluna do DataFrame:

#gorjetas.drop('day', axis=1)

# %% [markdown]
# # Importando o Seaborn

# %%
# !pip install seaborn==0.9.0
# Out:
# Collecting seaborn==0.9.0
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      -------------------------------------- 208.1/208.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.15.2 in c:\users\gracy\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.5.3)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\gracy\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.10.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\gracy\anaconda3\lib\site-packages (from seaborn==0.9.0) (3.7.0)
# Requirement already satisfied: numpy>=1.9.3 in c:\users\gracy\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gracy\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gracy\anaconda3\lib\site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\gracy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9.0) (1.16.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed seaborn-0.9.0

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.9.0
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\users\gracy\anaconda3\lib\site-packages
# Requires: matplotlib, numpy, pandas, scipy
# Required-by:

# %% [markdown]
# # Análise 1 - Valor da conta e gorjeta

# %%
gorjetas.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
valor_gorjeta = sns.scatterplot(x='valor_da_conta', y='gorjeta', data=gorjetas)

# %% [markdown]
# ## **Visualmente, o valor da gorjeta aumenta conforme aumenta o valor da conta**

# %%
gorjetas.shape[0] #ver o numero de dados que temos no banco
# Out:
# 244

# %%
print('A base de dados contém {} registros\n'.format(gorjetas.shape[0]))
print('Registros não nulos')
gorjetas.count()
# Out:
# A base de dados contém 244 registros
#
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## criando o campo porcentagem

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta']

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(2) #usar só 2 campos após a virgula

# %%
gorjetas.head(3)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='porcentagem', data = gorjetas)

# %% [markdown]
# **Visualmente o valor da conta não é proporcional ao valor da gorjeta**

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem',kind='line', data=gorjetas) #gráfico de linha

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data = gorjetas)

# %% [markdown]
# # Análise 2 - Sobremesa

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas[gorjetas.sobremesa == 'Sim'] #trazendo todos que tem sim para sobremesa
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 56            38.01     3.00       Sim        Sábado      Jantar
# 58            11.24     1.76       Sim        Sábado      Jantar
# 60            20.29     3.21       Sim        Sábado      Jantar
# 61            13.81     2.00       Sim        Sábado      Jantar
# 62            11.02     1.98       Sim        Sábado      Jantar
# ..              ...      ...       ...           ...         ...
# 234           15.53     3.00       Sim        Sábado      Jantar
# 236           12.60     1.00       Sim        Sábado      Jantar
# 237           32.83     1.17       Sim        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
#
#      total_de_pessoas  porcentagem
# 56                  4         0.08
# 58                  2         0.16
# 60                  2         0.16
# 61                  2         0.14
# 62                  2         0.18
# ..                ...          ...
# 234                 2         0.19
# 236                 2         0.08
# 237                 2         0.04
# 240                 2         0.07
# 241                 2         0.09
#
# [93 rows x 7 columns]

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %%
sns.catplot(x='sobremesa', y="gorjeta", data = gorjetas)#Gráfico categórico

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data = gorjetas) #hue altera a tonalidade

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa',col='sobremesa', data = gorjetas) #mesmo gráfico acima mas com 2 colunas

# %%
sns.relplot(x='valor_da_conta', y='gorjeta',col='sobremesa', data = gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', col = 'sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', col = 'sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', kind='line', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta',col='sobremesa', hue='sobremesa', kind='line', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem',col='sobremesa', hue='sobremesa', kind='line', data = gorjetas)

# %% [markdown]
# ## visualmente existe uma diferença no valor da gorjetas daqueles que pediram sobremesa e dos que não pediram

# %% [markdown]
# # Teste de hipótese

# %% [markdown]
#  **H<sup>null</sup>**
#
# >**A distribuição da taxa da gorjeta é a mesma dos dois grupos**
#
#  **H<sup>alt</sup>**
#
# >**A distribuição da taxa da gorjeta não é a mesma dos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print('O valor do pvalue é {}'.format(r.pvalue))
# Out:
# O valor do pvalue é 0.5266635660124415

# %% [markdown]
# **H<sup>null</sup>**
#
# **A distribuição da taxa da gorjeta é a mesma dos dois grupos**

# %% [markdown]
# # Análise 3 - Dias da semana

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x='dia_da_semana', y='valor_da_conta', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta',hue='dia_da_semana', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem',hue='dia_da_semana', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta',hue='dia_da_semana',col='dia_da_semana', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem',hue='dia_da_semana',col='dia_da_semana', data = gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem',hue='dia_da_semana',col='dia_da_semana', data = gorjetas)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()

# %%
print('A média geral das gorjetas é de {}'.format(media_geral_gorjetas))
# Out:
# A média geral das gorjetas é de 2.99827868852459

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
# C:\Users\Gracy\AppData\Local\Temp\ipykernel_13280\1513838919.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# # Teste de Hipótese

# %% [markdown]
# **H<sup>null</sup>**
#
# >**A distribuição do valor da conta é igual no sábado e no domingo**
#
#  **H<sup>alt</sup>**
#
# >**A distribuição do valor da conta não é igual no sábado e no domingo**

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
r2 = ranksums(valor_conta_domingo, valor_conta_sabado)
print('O valor do p-value é {}'.format(r2.pvalue))
# Out:
# O valor do p-value é 0.3576728477868443

# %% [markdown]
# **H<sup>null</sup>**
#
# >**A distribuição do valor da conta é igual no sábado e no domingo**

# %% [markdown]
# # Análise 4 - Hora do dia

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', kind='swarm',data=gorjetas)

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <Axes: xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <Axes: xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.distplot(almoco)
# Out:
# <Axes: xlabel='valor_da_conta'>

# %%
sns.distplot(almoco, kde=False)
# Out:
# <Axes: xlabel='valor_da_conta'>

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").valor_da_conta

# %%
sns.distplot(jantar)
# Out:
# <Axes: xlabel='valor_da_conta'>

# %%
sns.distplot(jantar, kde=False)
# Out:
# <Axes: xlabel='valor_da_conta'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()
# Out:
# C:\Users\Gracy\AppData\Local\Temp\ipykernel_13280\1714704720.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby(['hora_do_dia']).mean()
#              valor_da_conta   gorjeta  total_de_pessoas  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088          2.411765     0.163971
# Jantar            20.797159  3.102670          2.630682     0.159773

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']] #mostrando só o que queremos
# Out:
# C:\Users\Gracy\AppData\Local\Temp\ipykernel_13280\49752479.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']] #mostrando só o que queremos
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
#
# > **A distribuição do valor da conta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
#
# > **A distribuição do valor da conta não é igual no jantar e no almoço**

# %%
r2 = ranksums(jantar, almoco)

# %%
print('O valor do p-value é de {}'.format(r2.pvalue))
# Out:
# O valor do p-value é de 0.0011791039723641672

# %% [markdown]
# **H<sup>alt</sup>**
#
# > **A distribuição do valor da conta não é igual no jantar e no almoço**

# %% [markdown]
# ## Teste de hipótese 2

# %% [markdown]
# **H<sup>null</sup>**
#
# >**A distribuição da taxa da gorjeta é igual no jantar e no almoço**
#
#  **H<sup>alt</sup>**
#
# >**A distribuição da taxa da gorjeta não é igual no jantar e no almoço**

# %%
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
r3 = ranksums(porcentagem_almoco, porcentagem_jantar)
print('O valor do p-value é de {}'.format(r3.pvalue))
# Out:
# O valor do p-value é de 0.2602493995587126

# %% [markdown]
# **H<sup>null</sup>**
#
# >**A distribuição da taxa da gorjeta é igual no jantar e no almoço**
